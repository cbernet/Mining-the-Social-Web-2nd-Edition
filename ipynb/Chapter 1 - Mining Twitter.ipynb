# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = ''
CONSUMER_SECRET =''
OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x102edd8d0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977
FR_WOE_ID = 23424819

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
fr_trends = twitter_api.trends.place(_id=FR_WOE_ID)

print world_trends
print
print us_trends
print 
print fr_trends
# Out:
# [{u'created_at': u'2014-02-10T13:12:20Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23G2BIllNeverGetOverYou', u'query': u'%23G2BIllNeverGetOverYou', u'name': u'#G2BIllNeverGetOverYou', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22GameOfThrones+Dizikitte%C4%B0zlenir%22', u'query': u'%22GameOfThrones+Dizikitte%C4%B0zlenir%22', u'name': u'GameOfThrones Dizikitte\u0130zlenir', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23Ask5SOS', u'query': u'%23Ask5SOS', u'name': u'#Ask5SOS', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Aly+Hamil+Anak+IqbaalCJR%22', u'query': u'%22Aly+Hamil+Anak+IqbaalCJR%22', u'name': u'Aly Hamil Anak IqbaalCJR', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Aly+Pacar+NabilahJKT48%22', u'query': u'%22Aly+Pacar+NabilahJKT48%22', u'name': u'Aly Pacar NabilahJKT48', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23G2BWeGotYourBackChichay', u'query': u'%23G2BWeGotYourBackChichay', u'name': u'#G2BWeGotYourBackChichay', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23FreeIranianSoldiers', u'query': u'%23FreeIranianSoldiers', u'name': u'#FreeIranianSoldiers', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23PeliculaQueAmo', u'query': u'%23PeliculaQueAmo', u'name': u'#PeliculaQueAmo', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Michael+Sam%22', u'query': u'%22Michael+Sam%22', u'name': u'Michael Sam', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Go+San+Mig%22', u'query': u'%22Go+San+Mig%22', u'name': u'Go San Mig', u'promoted_content': None, u'events': None}], u'as_of': u'2014-02-10T13:20:05Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-02-10T13:16:30Z', u'trends': [{u'url': u'http://twitter.com/search?q=%22Michael+Sam%22', u'query': u'%22Michael+Sam%22', u'name': u'Michael Sam', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23Ask5SOS', u'query': u'%23Ask5SOS', u'name': u'#Ask5SOS', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23JoeyVotto', u'query': u'%23JoeyVotto', u'name': u'#JoeyVotto', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23virtualpayne', u'query': u'%23virtualpayne', u'name': u'#virtualpayne', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23happymonday', u'query': u'%23happymonday', u'name': u'#happymonday', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23PaulGoldschmidt', u'query': u'%23PaulGoldschmidt', u'name': u'#PaulGoldschmidt', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Marcus+Smart%22', u'query': u'%22Marcus+Smart%22', u'name': u'Marcus Smart', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22Valentine%27s+Day%22', u'query': u'%22Valentine%27s+Day%22', u'name': u"Valentine's Day", u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=Starbucks', u'query': u'Starbucks', u'name': u'Starbucks', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22The+Lego+Movie%22', u'query': u'%22The+Lego+Movie%22', u'name': u'The Lego Movie', u'promoted_content': None, u'events': None}], u'as_of': u'2014-02-10T13:20:06Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]
#
# [{u'created_at': u'2014-02-10T13:12:21Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23Adidas', u'query': u'%23Adidas', u'name': u'#Adidas', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23ShortTrack', u'query': u'%23ShortTrack', u'name': u'#ShortTrack', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23Sochi2014', u'query': u'%23Sochi2014', u'name': u'#Sochi2014', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23BrunoOffreMoiGagaSurFunRadio', u'query': u'%23BrunoOffreMoiGagaSurFunRadio', u'name': u'#BrunoOffreMoiGagaSurFunRadio', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23TheWalkingDead', u'query': u'%23TheWalkingDead', u'name': u'#TheWalkingDead', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=TWD', u'query': u'TWD', u'name': u'TWD', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=Beyonc%C3%A9', u'query': u'Beyonc%C3%A9', u'name': u'Beyonc\xe9', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=Suisses', u'query': u'Suisses', u'name': u'Suisses', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=VTC', u'query': u'VTC', u'name': u'VTC', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%22St+Valentin%22', u'query': u'%22St+Valentin%22', u'name': u'St Valentin', u'promoted_content': None, u'events': None}], u'as_of': u'2014-02-10T13:20:06Z', u'locations': [{u'woeid': 23424819, u'name': u'France'}]}]

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
print 
print json.dumps(fr_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-02-10T13:12:20Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23G2BIllNeverGetOverYou",
#     "query": "%23G2BIllNeverGetOverYou",
#     "name": "#G2BIllNeverGetOverYou",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22GameOfThrones+Dizikitte%C4%B0zlenir%22",
#     "query": "%22GameOfThrones+Dizikitte%C4%B0zlenir%22",
#     "name": "GameOfThrones Dizikitte\u0130zlenir",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Ask5SOS",
#     "query": "%23Ask5SOS",
#     "name": "#Ask5SOS",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Aly+Hamil+Anak+IqbaalCJR%22",
#     "query": "%22Aly+Hamil+Anak+IqbaalCJR%22",
#     "name": "Aly Hamil Anak IqbaalCJR",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Aly+Pacar+NabilahJKT48%22",
#     "query": "%22Aly+Pacar+NabilahJKT48%22",
#     "name": "Aly Pacar NabilahJKT48",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23G2BWeGotYourBackChichay",
#     "query": "%23G2BWeGotYourBackChichay",
#     "name": "#G2BWeGotYourBackChichay",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FreeIranianSoldiers",
#     "query": "%23FreeIranianSoldiers",
#     "name": "#FreeIranianSoldiers",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PeliculaQueAmo",
#     "query": "%23PeliculaQueAmo",
#     "name": "#PeliculaQueAmo",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Michael+Sam%22",
#     "query": "%22Michael+Sam%22",
#     "name": "Michael Sam",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Go+San+Mig%22",
#     "query": "%22Go+San+Mig%22",
#     "name": "Go San Mig",
#     "promoted_content": null,
#     "events": null
#    }
#   ],
#   "as_of": "2014-02-10T13:20:05Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-02-10T13:16:30Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Michael+Sam%22",
#     "query": "%22Michael+Sam%22",
#     "name": "Michael Sam",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Ask5SOS",
#     "query": "%23Ask5SOS",
#     "name": "#Ask5SOS",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JoeyVotto",
#     "query": "%23JoeyVotto",
#     "name": "#JoeyVotto",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23virtualpayne",
#     "query": "%23virtualpayne",
#     "name": "#virtualpayne",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23happymonday",
#     "query": "%23happymonday",
#     "name": "#happymonday",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PaulGoldschmidt",
#     "query": "%23PaulGoldschmidt",
#     "name": "#PaulGoldschmidt",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Marcus+Smart%22",
#     "query": "%22Marcus+Smart%22",
#     "name": "Marcus Smart",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Valentine%27s+Day%22",
#     "query": "%22Valentine%27s+Day%22",
#     "name": "Valentine's Day",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Starbucks",
#     "query": "Starbucks",
#     "name": "Starbucks",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22The+Lego+Movie%22",
#     "query": "%22The+Lego+Movie%22",
#     "name": "The Lego Movie",
#     "promoted_content": null,
#     "events": null
#    }
#   ],
#   "as_of": "2014-02-10T13:20:06Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-02-10T13:12:21Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23Adidas",
#     "query": "%23Adidas",
#     "name": "#Adidas",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ShortTrack",
#     "query": "%23ShortTrack",
#     "name": "#ShortTrack",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Sochi2014",
#     "query": "%23Sochi2014",
#     "name": "#Sochi2014",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BrunoOffreMoiGagaSurFunRadio",
#     "query": "%23BrunoOffreMoiGagaSurFunRadio",
#     "name": "#BrunoOffreMoiGagaSurFunRadio",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheWalkingDead",
#     "query": "%23TheWalkingDead",
#     "name": "#TheWalkingDead",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=TWD",
#     "query": "TWD",
#     "name": "TWD",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Beyonc%C3%A9",
#     "query": "Beyonc%C3%A9",
#     "name": "Beyonc\u00e9",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Suisses",
#     "query": "Suisses",
#     "name": "Suisses",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=VTC",
#     "query": "VTC",
#     "name": "VTC",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22St+Valentin%22",
#     "query": "%22St+Valentin%22",
#     "name": "St Valentin",
#     "promoted_content": null,
#     "events": null
#    }
#   ],
#   "as_of": "2014-02-10T13:20:06Z",
#   "locations": [
#    {
#     "woeid": 23424819,
#     "name": "France"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
print us_trends_set
# Out:
# set([u'#Ask5SOS', u'Michael Sam'])
# set([u'#virtualpayne', u'#happymonday', u'Marcus Smart', u'#JoeyVotto', u"Valentine's Day", u'#Ask5SOS', u'Michael Sam', u'The Lego Movie', u'#PaulGoldschmidt', u'Starbucks'])

# %%
fr_trends_set = set([trend['name'] 
                     for trend in fr_trends[0]['trends']]) 
print fr_trends_set
# Out:
# set([u'Beyonc\xe9', u'VTC', u'#ShortTrack', u'#TheWalkingDead', u'#Sochi2014', u'TWD', u'Suisses', u'St Valentin', u'#BrunoOffreMoiGagaSurFunRadio', u'#Adidas'])

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#Suisses' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# %%
print search_results.keys()
print len(statuses)
# metadata concerns my search
# statuses contains 100 tweets
# Out:
# [u'search_metadata', u'statuses']
# 100

# %%
for tweet in statuses[:5]:
    print '**** tweet', tweet['id'] 
    print tweet['coordinates'] # seems often None. I also decided not to share mine. try and find coordinates though!
    print tweet['text']
# Out:
# **** tweet 432892238520418304
# None
# RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples européens pensent tout bas...
# #Immigration
# #CHvote
# **** tweet 432889144792989698
# None
# Les #Suisses veulent moins d'étrangers en masse chez eux http://t.co/BqzdPyErWE
# **** tweet 432888518810279936
# None
# RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples européens pensent tout bas...
# #Immigration
# #CHvote
# **** tweet 432887564471500801
# None
# Can't believe I left #America for this shit: Les #Suisses veulent limiter la libre circulation http://t.co/2QiyjoN8YL #idiot #author #racism
# **** tweet 432887509266468864
# None
# RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples européens pensent tout bas...
# #Immigration
# #CHvote

# %%
# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
        print 'next_results', next_results
    except KeyError, e: # No more results when next_results doesn't exist
        print 'exit loop'
        break
        
    # next results has the following form: 
    # In [11]: next_results = '?max_id=432809959504752639&q=%23Suisses&count=100&include_entities=1'
    #
    # it contains the list of arguments to use to get the next batch of results:
    # 
    # In [12]: next_results[1:].split("&")
    # Out[12]: 
    # ['max_id=432809959504752639',
    #  'q=%23Suisses',
    #  'count=100',
    #  'include_entities=1']

    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    print kwargs
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
# Out:
# Length of statuses 100
# next_results ?max_id=432809959504752639&q=%23Suisses&count=100&include_entities=1
# {u'q': u'%23Suisses', u'count': u'100', u'include_entities': u'1', u'max_id': u'432809959504752639'}
# Length of statuses
#  200
# next_results ?max_id=432633945411567616&q=%2523Suisses&count=100&include_entities=1
# {u'q': u'%2523Suisses', u'count': u'100', u'include_entities': u'1', u'max_id': u'432633945411567616'}
# Length of statuses
#  200
# exit loop
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\u00e9ens pensent tout bas...\n#Immigration\n#CHvote",
#  "in_reply_to_status_id": null,
#  "id": 432892238520418304,
#  "favorite_count": 0,
#  "source": "web",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 1145230752,
#     "indices": [
#      3,
#      15
#     ],
#     "id_str": "1145230752",
#     "screen_name": "maximussuum",
#     "name": "MAXIMVS \u042f"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      21,
#      29
#     ],
#     "text": "Suisses"
#    },
#    {
#     "indices": [
#      120,
#      132
#     ],
#     "text": "Immigration"
#    },
#    {
#     "indices": [
#      133,
#      140
#     ],
#     "text": "CHvote"
#    }
#   ],
#   "urls": []
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 4,
#  "id_str": "432892238520418304",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\u00e9ens pensent tout bas...\n#Immigration\n#CHvote",
#   "in_reply_to_status_id": null,
#   "id": 432886915386204160,
#   "favorite_count": 0,
#   "source": "web",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       4,
#       12
#      ],
#      "text": "Suisses"
#     },
#     {
#      "indices": [
#       103,
#       115
#      ],
#      "text": "Immigration"
#     },
#     {
#      "indices": [
#       116,
#       123
#      ],
#      "text": "CHvote"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 4,
#   "id_str": "432886915386204160",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1145230752,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/CoXxYZm8Xx",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://twitter.com/maximussuum/status/414579189761581057",
#        "display_url": "twitter.com/maximussuum/st\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1169,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "1145230752",
#    "profile_background_color": "C0DEED",
#    "listed_count": 19,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 1682,
#    "description": "\u00abLe public \u00e9tant roi de nom, quiconque dirige l'opinion du public est roi de fait.\u00bb Charles Maurras, #Fran\u00e7aisDeSouche QUAND MEME ! #TeamPoutine",
#    "friends_count": 1590,
#    "location": "Hollandie occup\u00e9e",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1145230752/1387680303",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "maximussuum",
#    "lang": "fr",
#    "profile_background_tile": false,
#    "favourites_count": 5352,
#    "name": "MAXIMVS \u042f",
#    "notifications": false,
#    "url": "https://t.co/CoXxYZm8Xx",
#    "created_at": "Sun Feb 03 13:57:02 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "Bern",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "fr",
#   "created_at": "Mon Feb 10 14:40:57 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "fr",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 491372021,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 184,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "491372021",
#   "profile_background_color": "C0DEED",
#   "listed_count": 3,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 4555,
#   "description": "Aime le pays des GG,le bon vin et la gastronomie sans oublier les jolies femmes.",
#   "friends_count": 493,
#   "location": "",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "BrasseurHbr41",
#   "lang": "fr",
#   "profile_background_tile": false,
#   "favourites_count": 36,
#   "name": "Kagouni",
#   "notifications": false,
#   "url": null,
#   "created_at": "Mon Feb 13 15:23:39 +0000 2012",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "lang": "fr",
#  "created_at": "Mon Feb 10 15:02:07 +0000 2014",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "fr",
#   "result_type": "recent"
#  }
# }

# %%
# Show one sample search result by slicing the list...
first_tweet = statuses[0]
# each tweet contains a lot of info...
print json.dumps(statuses[0], indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\u00e9ens pensent tout bas...\n#Immigration\n#CHvote",
#  "in_reply_to_status_id": null,
#  "id": 432892238520418304,
#  "favorite_count": 0,
#  "source": "web",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 1145230752,
#     "indices": [
#      3,
#      15
#     ],
#     "id_str": "1145230752",
#     "screen_name": "maximussuum",
#     "name": "MAXIMVS \u042f"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      21,
#      29
#     ],
#     "text": "Suisses"
#    },
#    {
#     "indices": [
#      120,
#      132
#     ],
#     "text": "Immigration"
#    },
#    {
#     "indices": [
#      133,
#      140
#     ],
#     "text": "CHvote"
#    }
#   ],
#   "urls": []
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 4,
#  "id_str": "432892238520418304",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\u00e9ens pensent tout bas...\n#Immigration\n#CHvote",
#   "in_reply_to_status_id": null,
#   "id": 432886915386204160,
#   "favorite_count": 0,
#   "source": "web",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       4,
#       12
#      ],
#      "text": "Suisses"
#     },
#     {
#      "indices": [
#       103,
#       115
#      ],
#      "text": "Immigration"
#     },
#     {
#      "indices": [
#       116,
#       123
#      ],
#      "text": "CHvote"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 4,
#   "id_str": "432886915386204160",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1145230752,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/CoXxYZm8Xx",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://twitter.com/maximussuum/status/414579189761581057",
#        "display_url": "twitter.com/maximussuum/st\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1169,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "1145230752",
#    "profile_background_color": "C0DEED",
#    "listed_count": 19,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 1682,
#    "description": "\u00abLe public \u00e9tant roi de nom, quiconque dirige l'opinion du public est roi de fait.\u00bb Charles Maurras, #Fran\u00e7aisDeSouche QUAND MEME ! #TeamPoutine",
#    "friends_count": 1590,
#    "location": "Hollandie occup\u00e9e",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1145230752/1387680303",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "maximussuum",
#    "lang": "fr",
#    "profile_background_tile": false,
#    "favourites_count": 5352,
#    "name": "MAXIMVS \u042f",
#    "notifications": false,
#    "url": "https://t.co/CoXxYZm8Xx",
#    "created_at": "Sun Feb 03 13:57:02 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "Bern",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "fr",
#   "created_at": "Mon Feb 10 14:40:57 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "fr",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 491372021,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 184,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "491372021",
#   "profile_background_color": "C0DEED",
#   "listed_count": 3,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 4555,
#   "description": "Aime le pays des GG,le bon vin et la gastronomie sans oublier les jolies femmes.",
#   "friends_count": 493,
#   "location": "",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "BrasseurHbr41",
#   "lang": "fr",
#   "profile_background_tile": false,
#   "favourites_count": 36,
#   "name": "Kagouni",
#   "notifications": false,
#   "url": null,
#   "created_at": "Mon Feb 13 15:23:39 +0000 2012",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "lang": "fr",
#  "created_at": "Mon Feb 10 15:02:07 +0000 2014",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "fr",
#   "result_type": "recent"
#  }
# }

# %%
print first_tweet['text']
# Out:
# RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples européens pensent tout bas...
# #Immigration
# #CHvote

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print 
print t['retweeted_status']

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 23
#
# {u'contributors': None, u'truncated': False, u'text': u'#MentionSomeoneImportantForYou God.', u'in_reply_to_status_id': None, u'id': 316944833233186816, u'favorite_count': 0, u'source': u'web', u'retweeted': False, u'coordinates': None, u'entities': {u'user_mentions': [], u'hashtags': [{u'indices': [0, 30], u'text': u'MentionSomeoneImportantForYou'}], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 23, u'id_str': u'316944833233186816', u'favorited': False, u'user': {u'follow_request_sent': None, u'profile_use_background_image': True, u'id': 56259379, u'verified': False, u'profile_text_color': u'3C3940', u'profile_image_url_https': u'https://si0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', u'profile_sidebar_fill_color': u'95E8EC', u'is_translator': False, u'geo_enabled': True, u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/yRX89YM4J0', u'indices': [0, 22], u'expanded_url': u'http://www.datpiff.com/mixtapes-detail.php?id=470069', u'display_url': u'datpiff.com/mixtapes-detai\u2026'}]}, u'description': {u'urls': []}}, u'followers_count': 105041, u'protected': False, u'location': u'', u'default_profile_image': False, u'id_str': u'56259379', u'utc_offset': -18000, u'statuses_count': 16691, u'description': u'#TheseAreTheWordsISaid LP', u'friends_count': 59615, u'profile_link_color': u'91785A', u'profile_image_url': u'http://a0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', u'notifications': None, u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', u'profile_background_color': u'000000', u'profile_banner_url': u'https://si0.twimg.com/profile_banners/56259379/1363388572', u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', u'name': u'Download the NEW LP!', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 6142, u'screen_name': u'hassanmusician', u'url': u'http://t.co/yRX89YM4J0', u'created_at': u'Mon Jul 13 02:18:25 +0000 2009', u'contributors_enabled': False, u'time_zone': u'Eastern Time (US & Canada)', u'profile_sidebar_border_color': u'000000', u'default_profile': False, u'following': None, u'listed_count': 64}, u'geo': None, u'in_reply_to_user_id_str': None, u'lang': u'en', u'created_at': u'Wed Mar 27 16:08:31 +0000 2013', u'in_reply_to_status_id_str': None, u'place': None, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}

# %%
import pprint 
pprint.pprint( first_tweet )
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Mon Feb 10 15:02:07 +0000 2014',
#  u'entities': {u'hashtags': [{u'indices': [21, 29], u'text': u'Suisses'},
#                              {u'indices': [120, 132],
#                               u'text': u'Immigration'},
#                              {u'indices': [133, 140], u'text': u'CHvote'}],
#                u'symbols': [],
#                u'urls': [],
#                u'user_mentions': [{u'id': 1145230752,
#                                    u'id_str': u'1145230752',
#                                    u'indices': [3, 15],
#                                    u'name': u'MAXIMVS \u042f',
#                                    u'screen_name': u'maximussuum'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 432892238520418304,
#  u'id_str': u'432892238520418304',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'lang': u'fr',
#  u'metadata': {u'iso_language_code': u'fr', u'result_type': u'recent'},
#  u'place': None,
#  u'retweet_count': 4,
#  u'retweeted': False,
#  u'retweeted_status': {u'contributors': None,
#                        u'coordinates': None,
#                        u'created_at': u'Mon Feb 10 14:40:57 +0000 2014',
#                        u'entities': {u'hashtags': [{u'indices': [4, 12],
#                                                     u'text': u'Suisses'},
#                                                    {u'indices': [103, 115],
#                                                     u'text': u'Immigration'},
#                                                    {u'indices': [116, 123],
#                                                     u'text': u'CHvote'}],
#                                      u'symbols': [],
#                                      u'urls': [],
#                                      u'user_mentions': []},
#                        u'favorite_count': 0,
#                        u'favorited': False,
#                        u'geo': None,
#                        u'id': 432886915386204160,
#                        u'id_str': u'432886915386204160',
#                        u'in_reply_to_screen_name': None,
#                        u'in_reply_to_status_id': None,
#                        u'in_reply_to_status_id_str': None,
#                        u'in_reply_to_user_id': None,
#                        u'in_reply_to_user_id_str': None,
#                        u'lang': u'fr',
#                        u'metadata': {u'iso_language_code': u'fr',
#                                      u'result_type': u'recent'},
#                        u'place': None,
#                        u'retweet_count': 4,
#                        u'retweeted': False,
#                        u'source': u'web',
#                        u'text': u"Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\xe9ens pensent tout bas...\n#Immigration\n#CHvote",
#                        u'truncated': False,
#                        u'user': {u'contributors_enabled': False,
#                                  u'created_at': u'Sun Feb 03 13:57:02 +0000 2013',
#                                  u'default_profile': True,
#                                  u'default_profile_image': False,
#                                  u'description': u"\xabLe public \xe9tant roi de nom, quiconque dirige l'opinion du public est roi de fait.\xbb Charles Maurras, #Fran\xe7aisDeSouche QUAND MEME ! #TeamPoutine",
#                                  u'entities': {u'description': {u'urls': []},
#                                                u'url': {u'urls': [{u'display_url': u'twitter.com/maximussuum/st\u2026',
#                                                                    u'expanded_url': u'https://twitter.com/maximussuum/status/414579189761581057',
#                                                                    u'indices': [0,
#                                                                                 23],
#                                                                    u'url': u'https://t.co/CoXxYZm8Xx'}]}},
#                                  u'favourites_count': 5352,
#                                  u'follow_request_sent': False,
#                                  u'followers_count': 1169,
#                                  u'following': False,
#                                  u'friends_count': 1590,
#                                  u'geo_enabled': False,
#                                  u'id': 1145230752,
#                                  u'id_str': u'1145230752',
#                                  u'is_translation_enabled': False,
#                                  u'is_translator': False,
#                                  u'lang': u'fr',
#                                  u'listed_count': 19,
#                                  u'location': u'Hollandie occup\xe9e',
#                                  u'name': u'MAXIMVS \u042f',
#                                  u'notifications': False,
#                                  u'profile_background_color': u'C0DEED',
#                                  u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                  u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                  u'profile_background_tile': False,
#                                  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1145230752/1387680303',
#                                  u'profile_image_url': u'http://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png',
#                                  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/431898011862458368/mV9OAfnY_normal.png',
#                                  u'profile_link_color': u'0084B4',
#                                  u'profile_sidebar_border_color': u'C0DEED',
#                                  u'profile_sidebar_fill_color': u'DDEEF6',
#                                  u'profile_text_color': u'333333',
#                                  u'profile_use_background_image': True,
#                                  u'protected': False,
#                                  u'screen_name': u'maximussuum',
#                                  u'statuses_count': 1682,
#                                  u'time_zone': u'Bern',
#                                  u'url': u'https://t.co/CoXxYZm8Xx',
#                                  u'utc_offset': 3600,
#                                  u'verified': False}},
#  u'source': u'web',
#  u'text': u"RT @maximussuum: Les #Suisses n'ont fait que dire tout haut ce que la plupart des peuples europ\xe9ens pensent tout bas...\n#Immigration\n#CHvote",
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#            u'created_at': u'Mon Feb 13 15:23:39 +0000 2012',
#            u'default_profile': True,
#            u'default_profile_image': False,
#            u'description': u'Aime le pays des GG,le bon vin et la gastronomie sans oublier les jolies femmes.',
#            u'entities': {u'description': {u'urls': []}},
#            u'favourites_count': 36,
#            u'follow_request_sent': False,
#            u'followers_count': 184,
#            u'following': False,
#            u'friends_count': 493,
#            u'geo_enabled': True,
#            u'id': 491372021,
#            u'id_str': u'491372021',
#            u'is_translation_enabled': False,
#            u'is_translator': False,
#            u'lang': u'fr',
#            u'listed_count': 3,
#            u'location': u'',
#            u'name': u'Kagouni',
#            u'notifications': False,
#            u'profile_background_color': u'C0DEED',
#            u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#            u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#            u'profile_background_tile': False,
#            u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg',
#            u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000801618822/86cc6f3291643c28aebf545b50937425_normal.jpeg',
#            u'profile_link_color': u'0084B4',
#            u'profile_sidebar_border_color': u'C0DEED',
#            u'profile_sidebar_fill_color': u'DDEEF6',
#            u'profile_text_color': u'333333',
#            u'profile_use_background_image': True,
#            u'protected': False,
#            u'screen_name': u'BrasseurHbr41',
#            u'statuses_count': 4555,
#            u'time_zone': None,
#            u'url': None,
#            u'utc_offset': None,
#            u'verified': False}}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:10], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps([ tag for tag in hashtags if tag.lower()!='mentionsomeoneimportantforyou'])
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\ud83d\udc4d",
#  "#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.",
#  "RT @hassanmusician: #MentionSomeoneImportantForYou God.",
#  "#MentionSomeoneImportantForYou @Louis_Tomlinson",
#  "#MentionSomeoneImportantForYou @Delta_Universe"
# ]
# [
#  "KathleenMariee_",
#  "AhhlicksCruise",
#  "itsravennn_cx",
#  "kandykisses_13",
#  "BMOLOGY",
#  "Linkin_Sunrise",
#  "hassanmusician",
#  "Louis_Tomlinson",
#  "Delta_Universe",
#  "bieberifiant_"
# ]
# [
#  "MentionSomeOneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou"
# ]
# ["NoHomo", "bebesito", "MyHeart", "Love"]
# [
#  "\u201c@KathleenMariee_:",
#  "#MentionSomeOneImportantForYou",
#  "@AhhlicksCruise",
#  ",",
#  "@itsravennn_cx"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

# just doing a counter for each list. We are NOT chaining the lists together.
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common(10) # top 10
    print
# Out:
# [(u'#MentionSomeoneImportantForYou', 92), (u'RT', 34), (u'my', 10), (u',', 6), (u'@justinbieber', 6), (u'&lt;3', 6), (u'My', 5), (u'and', 4), (u'I', 4), (u'te', 3)]
#
# [(u'justinbieber', 6), (u'Kid_Charliej', 2), (u'Cavillafuerte', 2), (u'touchmestyles_', 1), (u'aliceorr96', 1), (u'gymleeam', 1), (u'fienas', 1), (u'nayely_1D', 1), (u'angelchute', 1), (u'BigTittieAngel', 1)]
#
# [(u'MentionSomeoneImportantForYou', 94), (u'mentionsomeoneimportantforyou', 3), (u'NoHomo', 1), (u'Love', 1), (u'MentionSomeOneImportantForYou', 1), (u'MyHeart', 1), (u'bebesito', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
# this module is cool! should check how to add columns: 
# https://code.google.com/p/prettytable/
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +--------------------------------+-------+
# | Word                           | Count |
# +--------------------------------+-------+
# | #MentionSomeoneImportantForYou |    92 |
# | RT                             |    34 |
# | my                             |    10 |
# | ,                              |     6 |
# | @justinbieber                  |     6 |
# | &lt;3                          |     6 |
# | My                             |     5 |
# | and                            |     4 |
# | I                              |     4 |
# | te                             |     3 |
# +--------------------------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | justinbieber   |     6 |
# | Kid_Charliej   |     2 |
# | Cavillafuerte  |     2 |
# | touchmestyles_ |     1 |
# | aliceorr96     |     1 |
# | gymleeam       |     1 |
# | fienas         |     1 |
# | nayely_1D      |     1 |
# | angelchute     |     1 |
# | BigTittieAngel |     1 |
# +----------------+-------+
# +-------------------------------+-------+
# | Hashtag                       | Count |
# +-------------------------------+-------+
# | MentionSomeoneImportantForYou |    94 |
# | mentionsomeoneimportantforyou |     3 |
# | NoHomo                        |     1 |
# | Love                          |     1 |
# | MentionSomeOneImportantForYou |     1 |
# | MyHeart                       |     1 |
# | bebesito                      |     1 |
# +-------------------------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    '''returns the number of different words divided by the number of words'''
    return float(len(set(tokens)))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(status_texts):
    '''takes a list of tweet texts, and returns the average number of words per tweet'''
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.67610619469
# 0.955414012739
# 0.0686274509804
# 5.76530612245

# %%
pprint.pprint( status_texts[:10] )
# Out:
# [u'\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\U0001f44d',
#  u'#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.',
#  u'RT @hassanmusician: #MentionSomeoneImportantForYou God.',
#  u'#MentionSomeoneImportantForYou @Louis_Tomlinson',
#  u'#MentionSomeoneImportantForYou @Delta_Universe',
#  u'#MentionSomeoneImportantForYou @bieberifiant_',
#  u'RT @WubbyThoxD: #MentionSomeoneImportantForYou @Spidey_Gang \U0001f618',
#  u'#MentionSomeoneImportantForYou justin drew bieber, my life saver.',
#  u'#MentionSomeoneImportantForYou @MelissaMcilroy  I love you bby&lt;3',
#  u'#MentionSomeoneImportantForYou my @Albud7 :)']

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
for row in sorted(retweets, reverse=True)[:5]:
    pt.add_row(row)
pt.max_width['Text'] = 50
pt.align= 'l'
print pt
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 23    | hassanmusician | RT @hassanmusician: #MentionSomeoneImportantForYou |
# |       |                | God.                                               |
# | 21    | HSweethearts   | RT @HSweethearts: #MentionSomeoneImportantForYou   |
# |       |                | my high school sweetheart ❤💋                      |
# | 15    | LosAlejandro_  | RT @LosAlejandro_: ¿Nadie te menciono en           |
# |       |                | "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJA |
# |       |                | JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...  |
# | 9     | SCOTTSUMME     | RT @SCOTTSUMME: #MentionSomeoneImportantForYou My  |
# |       |                | Mum. Shes loving, caring, strong, all in one. I    |
# |       |                | love her so much ❤❤❤❤                              |
# | 7     | degrassihaha   | RT @degrassihaha: #MentionSomeoneImportantForYou I |
# |       |                | can't put every Degrassi cast member, crew member, |
# |       |                | and writer in just one tweet....                   |
# +-------+----------------+----------------------------------------------------+

# %%
# the sorting is done according to the first item in the tuple, for tuples of same size.
print (2,2,3) < (2,2,4)
# so no need to index by a key in a dict.
sorted( retweets , reverse=True)[:5]
# Out:
# True
# [(23,
#   u'hassanmusician',
#   u'RT @hassanmusician: #MentionSomeoneImportantForYou God.'),
#  (21,
#   u'HSweethearts',
#   u'RT @HSweethearts: #MentionSomeoneImportantForYou my high school sweetheart \u2764\U0001f48b'),
#  (15,
#   u'LosAlejandro_',
#   u'RT @LosAlejandro_: \xbfNadie te menciono en "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...'),
#  (9,
#   u'SCOTTSUMME',
#   u'RT @SCOTTSUMME: #MentionSomeoneImportantForYou My Mum. Shes loving, caring, strong, all in one. I love her so much \u2764\u2764\u2764\u2764'),
#  (7,
#   u'degrassihaha',
#   u"RT @degrassihaha: #MentionSomeoneImportantForYou I can't put every Degrassi cast member, crew member, and writer in just one tweet....")]

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book
orig_id = 317127304981667841
swiss_id = 432886915386204160 # from my french example
_retweets = twitter_api.statuses.retweets(id=swiss_id)
print [r['user']['screen_name'] for r in _retweets]
# Out:
# [u'eva_orel', u'ochon_pol', u'jorima83', u'claudine123456', u'OudonCh', u'a_nb01', u'ATossand', u'BrasseurHbr41', u'besomonkey', u'ManuHEIL', u'swissherr']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
counter = Counter(words)
word_counts = sorted(counter.values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %%
# another possibility. should also try and use pandas. 
sortedcounter = np.array( counter.most_common() ) 
plt.loglog(sortedcounter[:,1])
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data (data is e.g. the list of words)
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()
# Out:
# [u'\u201c@KathleenMariee_:', u'#MentionSomeOneImportantForYou', u'@AhhlicksCruise', u',', u'@itsravennn_cx', u',@kandykisses_13', u',', u'@BMOLOGY\u201d\U0001f44d', u'#MentionSomeoneImportantForYou', u'My']
# [u'KathleenMariee_', u'AhhlicksCruise', u'itsravennn_cx', u'kandykisses_13', u'BMOLOGY', u'Linkin_Sunrise', u'hassanmusician', u'Louis_Tomlinson', u'Delta_Universe', u'bieberifiant_']
# [u'MentionSomeOneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou', u'MentionSomeoneImportantForYou']

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts
# Out:
# [23, 1, 21, 1, 5, 2, 2, 2, 3, 1, 1, 1, 1, 9, 1, 1, 1, 15, 1, 1, 1, 2, 1, 1, 7, 6, 1, 3, 1, 1, 1, 1, 1]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
# Out:
# [ 3.13549422  0.          3.04452244  0.          1.60943791  0.69314718
#   0.69314718  0.69314718  1.09861229  0.          0.          0.          0.
#   2.19722458  0.          0.          0.          2.7080502   0.          0.
#   0.          0.69314718  0.          0.          1.94591015  1.79175947
#   0.          1.09861229  0.          0.          0.          0.          0.        ]
